# %% [markdown]
# # General introduction to BASH

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('oxuRxtrO2Ag')

# %% [markdown]
# # NUMPY in 15 minutes...

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('xECXZ3tyONo')

# %% [markdown]
# # General introduction about SciPy and numpy

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lKcwuPnSHIQ')

# %% [markdown]
# # Solving Differential Equations with numpy

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VV3BnroVjZo')
